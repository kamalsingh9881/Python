# %% [markdown]
# 1. What are the differences between operators and values in the following?
# *	operator
# 'hello'	value
# -87.8	value
# -	operator
# /	operator
# +	operator
# 6	value
#
# Ans: 	Operators are the symbols in programming language which tells compiler or interpreator to perform specific assignment , logical, relational and mathmatical operation whereas values are the are the entities which can be manuplated or those entites in which some operations can be performed.
#
# 2. What is the difference between string and variable?
# Spam 	variable
# 'spam'  	datatype
#
# Ans:	String is a datatype which holds sequence of characters wheres variables is a memory locations consist a name to extract the data that will hold in this memory location.
#
# 3. Describe three different data forms.
# Ans:
#
# Integer : this form of data contains all the integers either positve or negative
# String : this form of data contains the sequence of characters may or may not be same
# Boolean: this form of data contains two values either true or false
#
# 4. What makes up an expression? What are the functions of all expressions?
# Ans:	Expression is a combination of constants, variable, operators and functions. All expressions are used by interpreter to manuplate data.
#
#
# 5. In this chapter, assignment statements such as spam = 10 were added. What's the difference between a declaration and an expression?
# Ans:	Declaration is informing compiler about the details of a variable, functions like their name and the data they holds and expression are used by interpreter to manuplate data
#
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
# Ans . 	22
#
# 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3
# Ans.	Output of both will be ‘spamspamspam’
#
# 8. Why is it that eggs is a true variable name but 100 is not?
# Ans.	Because variable name cant be a constant it should be a charter, symbol or sequence of character without space therfore 100 is not a variable it’s a value
#
# 9. Which of the following three functions may be used to convert a value to an integer, a floating-point number, or a string?
# Ans.	For integer Int(), for floting point number float() , for string  str()
#
# 10. What is the error caused by this expression? What would you do about it?
# 'I have eaten ' + 99 + ' burritos.'
# Ans.	Can only concatenate str (not “int”) to str
